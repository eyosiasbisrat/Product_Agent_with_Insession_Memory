# %%
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
load_dotenv()

llm = ChatAnthropic(
    model="claude-sonnet-4-5"
)

# %%
with open("blood_work.txt","r") as f:
    blood_report= f.read()

print(blood_report[:200])
# Out:
# Patient: Abraham Belay, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL 
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# # Blood Report Analysis for Abraham Belay
#
# ## COMPLETE BLOOD COUNT (CBC)
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5 g/dL
# - Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0 x10^3/uL
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400 x10^3/uL
#
# ## LIPID PANEL
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200 mg/dL
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100 mg/dL
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40 mg/dL
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150 mg/dL
#
# ## METABOLIC PANEL
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99 mg/dL
# - HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3 mg/dL
# - eGFR: 82 mL/min | Status: NORMAL | Reference: >60 mL/min
#
# ## LIVER FUNCTION
# - ALT: 28 U/L | Status: NORMAL | Reference: 7–40 U/L
# - AST: 25 U/L | Status: NORMAL | Reference: 10–40 U/L
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2 mg/dL
#
# ---
#
# **Summary:**
# - **Abnormal Results:** 4 out of 15 tests
# - **Concerns:** Lipid panel shows elevated cardiovascular risk markers (high total cholesterol, high LDL, low HDL, high triglycerides)

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of. 
   Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)

print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# ## HEALTH SUMMARY
#
# Your blood report shows that while your blood sugar, liver, kidney, and blood cell counts are healthy, you have a significant cholesterol problem that increases your heart disease risk. Your total cholesterol and bad cholesterol (LDL) are high, your good cholesterol (HDL) is low, and your triglycerides are elevated. This combination indicates your body is storing too much fat in the blood, likely due to dietary habits high in unhealthy fats and oils. The good news is that with proper Indian dietary modifications focusing on heart-healthy foods, you can significantly improve these numbers within 3-6 months.
#
# ---
#
# ## INDIAN DIET PLAN
#
# ### FOODS TO AVOID
#
# - **Deep-fried items:** Samosas, pakoras, puris, vadas, bhajias, French fries, fried papad
# - **Heavy oil-based curries and gravies:** Butter chicken, korma, coconut-based gravies
# - **Full-fat dairy:** Whole milk, full-fat paneer, ghee, butter, cream, khoya-based sweets
# - **Bakery and processed foods:** Biscuits, cakes, pastries, namkeens, chips, mathri
# - **Red meat and organ meats:** Mutton, beef, liver, brain curry
# - **Coconut products:** Coconut oil for cooking, grated coconut in excess
# - **Trans fats:** Vanaspati, dalda, reused cooking oil
# - **Egg yolks:** Limit to 2-3 per week
# - **White refined foods:** Maida products, white bread, polished white rice in excess
#
# ### FOODS TO EAT MORE OF
#
# - **Whole grains:** Brown rice, oats, dalia (broken wheat), jowar, bajra, ragi rotis, quinoa
# - **Lentils and legumes:** All dals (moong, masoor, toor, chana), rajma, chole, sprouts
# - **Fiber-rich vegetables:** Bhindi, beans, broccoli, cauliflower, cabbage, bottle gourd, ridge gourd, bitter gourd, carrots, spinach, methi
# - **Fruits:** Apples, guava, papaya, oranges, pomegranate, berries (2-3 servings daily)
# - **Healthy fats - Nuts and seeds:** Almonds, walnuts (4-5 daily), flaxseeds, chia seeds, sunflower seeds
# - **Fatty fish:** Salmon, mackerel, sardines (2-3 times weekly)
# - **Low-fat dairy:** Skimmed milk, low-fat curd, low-fat paneer
# - **Cooking methods:** Steamed idli, dhokla; grilled, roasted or tandoori items
# - **Healthy oils (limited quantity):** Mustard oil, rice bran oil, olive oil (2-3 teaspoons/day)
# - **Garlic, onion, ginger, turmeric:** Use liberally in cooking
# - **Green tea or black coffee:** 2-3 cups daily (without sugar)
